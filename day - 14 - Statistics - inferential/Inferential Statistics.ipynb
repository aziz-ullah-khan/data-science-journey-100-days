# %% [markdown]
# # 📘 Inferential Statistics
#
# ✍️ Aziz Ullah Khan | 📅 March 09, 2024
#
# ---
#
# ## 🚀 Overview
#
#
# Inferential Statistics is the prediction about population based on sample data.
#
# ---
#
# ## 📚 Table of Contents
#
# 1. [Estimators and Estimates](#1.-Estimators-and-Estimates)
# 2. [Confidence Intervals and the Margin of Error](#2.-Confidence-Intervals-and-the-Margin-of-Error)
# 3. [Fourmulas for Confidence Interval](#3.-Fourmulas-for-Confidence-Interval)
# 4. [Summary](#4.-Summary)

# %% [markdown]
# # 1. Estimators and Estimates
# ---
#
# Estimator is a mathematical function which basically approximate population parameter based on sample information.
#
# $$
# \begin{array}{ccc}
# \hline
# \textbf{Term} & \textbf{Estimator} & \textbf{Parameter} \\
# \text{Mean} & \overline{x} & 𝜇 \\
# \text{Variance} & s^2 & 𝜎^2 \\
# \text{Correlation} & r & ρ \\
# \hline
# \end{array}
# $$
#
#
# In the above table the sample info estimate the population parameters.
#
# **Estimate-** \
# Estimate is the ouput of an estimator, and are of two types:
# 1. Point Estimates \
#     A single value estimation like 1, 2.4 ..
# 2. Confidence Interval estimates\
#     Estimating an interval like (1, 30), (100, 200) ..
#
#
# Note: Confidence intervals are more precise and hence using mostly.

# %% [markdown]
# # 2. Confidence Intervals and the Margin of Error
# ---
#
# **Confidence Interval** is an interval within which we are confident that the population parameters will fall.
#
# ![image.png](attachment:image.png)
#
# $(1-α)$ is the level of confidence. We are $(1-α)*100%$ confident that the population parameter will fall in the specified interval.
#
# Common alphas are: 0.01, 0.05, 0.1.
#
# $[\overline{x} - \text{ME}, \, \overline{x} + \text{ME}]$
#
# $ME = \text{reliability factor} \times \frac{\text{standard deviation}}{\sqrt{\text{sample size}}}$

# %% [markdown]
# # 3. Fourmulas for Confidence Interval
# ---
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Summary
# ---
#
# - Inferential Statistics is the prediction about population based on sample data.
# - Estimator is a mathematical function which basically approximate population parameter based on sample information.
# - Confidence Interval is an interval within which we are confident that the population parameters will fall.

# %% [markdown]
# 🌐 Feel free to connect with [me](https://www.linkedin.com/in/aziz-ullah-khan/) if you have questions or want to discuss this fascinating journey further! Let's continue exploring together.
