# %% [markdown]
# # 📘 Descriptive Statistics
#
# ✍️ Aziz Ullah Khan | 📅 March 02, 2024
#
# ---
#
# ## 🚀 Overview
#
#
# Descriptive statistics involve summarizing and analyzing data to reveal its key features, providing a clear overview of central tendencies, dispersion, and data distribution.
#
# ---
#
# ## 📚 Table of Contents
#
# 1. [Type of data](#1.-Types-of-data)
# 2. [Levels of measurement](#2.-Levels-of-measurement)
# 3. [Representation of categorical variables](#3.-Representation-of-categorical-variables)

# %% [markdown]
# # 1. Types of data
# ---
#
# There are two types of data; categorical and numerical.
#
# **1. Categorical Data:**
# Categrocial data represent groups or categories.
#
# **2. Numerical data:**
# Numerical data represent numbers and may be discrete or continuous.
#
# **2.1 Discrete:**
# Data which is finite to count like number of balls.
#
# **2.2 Continuous:**
# Continuous is inifinite and imppossible to count like temperature.

# %% [markdown]
# # 2. Levels of measurement
# ---
#
# There are two levels of measurement i.e qualitative and quantitative.
#
# **1. Qualitative:**
# Qualitative may be Nominal or Ordinal.
#
# **1.1 Nominal:**
# Categories without inherent order.\
# Examples: Gender, colors.
#
# **1.2 Ordinal Level:**
# Meaningful order, uneven intervals.\
# Examples: Education levels.
#
# **2 Quantitative:** \
# **2.1 Interval Level:**
# Meaningful order, uniform intervals, no true zero.\
# Examples: Temperature (Celsius, Fahrenheit).
#
# **2.2 Ratio Level:**
# Meaningful order, uniform intervals, true zero.\
# Examples: Height, weight, income.

# %% [markdown]
# # Representation of categorical variables
# ---
#
# **Frequency Distribution Table-**
#
# ![image.png](attachment:image.png)
#
#
# **Bar charts-**
#
# ![image-2.png](attachment:image-2.png)
#
# **Pie Chart-**
#
# ![image-3.png](attachment:image-3.png)
#
# **Pareto chart-**
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # 4. Summary
# ---
#
# - Descriptive statistics involve summarizing and analyzing data to reveal its key features, providing a clear overview of central tendencies, dispersion, and data distribution.
# - Two types of data; categorical and numerical.
# - Two levels of measuremen i.e qualitative and quantitative.

# %% [markdown]
# 🌐 Feel free to connect with [me](https://www.linkedin.com/in/aziz-ullah-khan/) if you have questions or want to discuss this fascinating journey further! Let's continue exploring together.
