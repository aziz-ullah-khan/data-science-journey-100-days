# %% [markdown]
# # 📘 Probability - Bayesian Inference
#
# ✍️ **Author:** Aziz Ullah Khan | 📅 **Date:** February 25, 2024
#
# ---
#
# ## 🚀 Overview
#
# Bayesian inference in simple words is adjusting your beliefs upon new information by using probability.
#
# ---
#
# ## 📚 Table of Contents
#
# 1. [Bayesian Notation](#1.-Bayesian-Notation)
# 2. [Intersection](#2.-Intersection)
# 3. [Union](#3.-Union)
# 4. [Mutually Exclusive Sets](#4.-Mutually-Exclusive-Sets)
# 5. [Independent and Dependent Events](#5.-Independent-and-Dependent-Events)
# 6. [Conditional Probability](#6.-Conditional-Probability)
# 7. [Law of total probability](#7.-Law-of-total-probability)
# 8. [Additive Law](#8.-Additive-Law)
# 9. [The Multiplication Rule](#9.-The-Multiplication-Rule)
# 10. [Bayes’ Law](#10.-Bayes’-Law)
# 11. [Summary](#11.-Summary)

# %% [markdown]
# # 1. Bayesian Notation
# ---
# A **set** is a collection of elements, which hold certain values. Additionally, every event has a set of outcomes that satisfy it.
#
#
# The *null-set* (or *empty set* ), denoted $∅$, is an set which contain no values.
#
#
# $$ x \in A$$
#
# Here, $x$ is the Element and $A$ is the **set**.
#
# $$
# \begin{array}{ccc}
# \hline
# \textbf{Notation} & \textbf{Interpretation} & \textbf{Example} \\
# \hline
# 𝑥 \in 𝐴 & \text{Element $x$ is a part of set $A$.} & 4 \in \text{All even numbers} \\
# A \ni 𝑥 & \text{Set $A$ contains element $x$.} & \text{All even numbers} \ni 2\  \\
# 𝑥 \notin 𝐴 & \text{Element $x$ is NOT a part of set $A$.} & 1 \notin \text{All even numbers} \\
# \forall 𝑥: & \text{For all/any $x$ such that...} & \forall x: x \in 𝐴𝑙𝑙\ (\text{all numbers}) \\
# 𝐴 \subseteq 𝐵 & \text{$A$ is a subset of $B$.} & 𝐸𝑣𝑒𝑛\ 𝑛𝑢𝑚𝑏𝑒𝑟𝑠\ ⊆\ 𝐼𝑛𝑡𝑒𝑔𝑒𝑟s \\
# \hline
# \end{array}
# $$
#
#
# **Remember!**
# Every set has at least 2 subsets.
# - $𝐴 ⊆ 𝐴$
# -  $∅ ⊆ A$

# %% [markdown]
# # 2. Intersection
# ---
#
# The **intersection** of two or more events expresses the set of outcomes that satisfy all the events simultaneously. Graphically, this is the area where the sets intersect.
#
# $$A ∩ B$$
#
# ![image-2.png](attachment:image-2.png)
#
# The shaded portion above is the intersection bewteen $A$ and $B$.

# %% [markdown]
# # 3. Union
# ---
#
# The **union** of two or more events expresses the set of outcomes that satisfy at least one of the events.
# Graphically, this is the area that includes both sets.
#
# $$A ∪ B = A + B - A ∩ B $$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Mutually Exclusive Sets
# ---
# Sets with no overlapping elements are called **mutually exclusive**. Graphically, their circles never touch.
#
# $$ 𝑨 ∩ 𝑩 = ∅ $$
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. Independent and Dependent Events
# ---
#
# If the likelihood of event A occurring **(P(A))** is affected event B occurring, then we say that A and B are dependent events. Alternatively, if it isn’t – the two events are independent.
#
# **Conditional probability:**
#
# $P(A|B)$ is the prbability of Event A given B.
#
# **Independent:**
#
# The outcome of A does not depend on the outcome
# of B.
# - $𝑃(𝐴|𝐵) = 𝑃(𝐴)$
#
# **Dependent:**
#
# The outcome of A depends on the outcome of B.
# - $𝑃(𝐴|𝐵) ≠ 𝑃(𝐴)$

# %% [markdown]
# # 6. Conditional Probability
# ---
# For any two events A and B, such that the likelihood of B occurring is greater than 0 $(𝑃(𝐵) > 0)$, the conditional probability formula states the following.
#
# $$𝑃(𝐴|𝐵) = \frac{𝑃(𝐴 ∩ 𝐵)}{𝑃(𝐵)}$$
#
# Here, $𝑃(𝐴|𝐵)$ is the probability of A given B, $𝑃(𝐴 ∩ 𝐵)$ is probability of intersection and $P(B)$ is probability of B.
#
# **Remember**
# - $𝑃(𝐴|𝐵) ≠ 𝑃(B|A)$

# %% [markdown]
# # 7. Law of total probability
# ---
# The law of total probability dictates that for any set A, which is a union of many mutually exclusive sets $𝐵_1,𝐵_2, … ,B_n$, its probability equals the following sum.
#
# $$𝑃(𝐴) = 𝑃(𝐴|𝐵_1) × 𝑃(𝐵_1) + 𝑃(𝐴|𝐵_2) × 𝑃(𝐵_2) + ⋯ + 𝑃(𝐴|B_n) × 𝑃(𝐵_n) $$

# %% [markdown]
# # 8. Additive Law
# ---
# The additive law calculates the probability of the union based on the probability of the individual sets it accounts for.
#
# $$ 𝑃(𝐴 ∪ 𝐵) = 𝑃(𝐴) + 𝑃(𝐵) − 𝑃(𝐴 ∩ 𝐵)$$

# %% [markdown]
# # 9. The Multiplication Rule
# ---
#
# The multiplication rule calculates the probability of the intersection based on the conditional probability.
#
# $$𝑃(𝐴 ∩ 𝐵) = 𝑃(𝐴|𝐵) × 𝑃(𝐵)$$

# %% [markdown]
# # 10. Bayes’ Law
# ---
# Bayes’ Law helps us understand the relationship between two events by computing the different conditional probabilities. We also call it Bayes’ Rule or Bayes’ Theorem.
#
# $$𝑃(𝐴|𝐵) = \frac{𝑃(𝐵|𝐴) × 𝑃(𝐴)}{𝑃(𝐵)}$$

# %% [markdown]
# # 11. Summary
#
# - A set is a collection of elements, which hold certain values. Additionally, every event has a set of outcomes that satisfy it.
# - The intersection of two or more events expresses the set of outcomes that satisfy all the events simultaneously.
# - The union of two or more events expresses the set of outcomes that satisfy at least one of the events.
# - Sets with no overlapping elements are called mutually exclusive.
# - Events may be dependent or independent

# %% [markdown]
# 🌐 Feel free to connect with [me](https://www.linkedin.com/in/aziz-ullah-khan/) if you have questions or want to discuss this fascinating journey further! Let's continue exploring together.
